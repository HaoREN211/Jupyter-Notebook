# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# networkx有四种图 Graph 、DiGraph、MultiGraph、MultiDiGraph，分别为无多重边无向图、无多重边有向图、有多重边无向图、有多重边有向图。

# %%
G = nx.random_graphs.barabasi_albert_graph(100,1)   #生成一个BA无标度网络G
nx.draw(G)                          #绘制网络G
plt.savefig("ba.png")           #输出方式1: 将图像存为一个png格式的图片文件
plt.show()
# Out:
# c:\users\hao.ren3\appdata\local\programs\python\python37\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# G.add_node('a')#添加点a
#
# G.add_node(1,1)#用坐标来添加点
#
# G.add_edge('x','y')#添加边,起点为x，终点为y
#
# G.add_weight_edges_from([('x','y',1.0)])#第三个输入量为权值
#
# 也可以list = [[('a','b',5.0),('b','c',3.0),('a','c',1.0)]
#
# G.add_weight_edges_from([(list)])

# %%
#创建空的网络图
G = nx.Graph()

G.add_node('0', color='r')
G.add_node('1', color='k')
G.add_node('2', color='b')
G.add_node('3', color='b')
G.add_node('4', color='k')
G.add_node('5', color='r')
G.add_node('6', color='b')
list = [
    ('5','1',0.14),
     ('5','2',0.14),
     ('1','2',0.14),
    ('0','1',0.58),
    ('0','6',0.94),
    ('0','4',0.14),
    ('3','6',0.14)]
G.add_weighted_edges_from(list)
ncolor = ['r', 'k', 'b', 'b', 'k', 'r', 'b']

# %%
nx.draw(G, with_labels = True, node_color=ncolor)
plt.show()
# Out:
# c:\users\hao.ren3\appdata\local\programs\python\python37\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
color = nx.get_node_attributes(G, 'color')
print (color)
# Out:
# {'0': 'red'}
